# %% [markdown]
# ** This notebook does not keep up with real-time earthquakes, but only shows the current quakes at the time it was last ran.

# %% [markdown]
# # Earthquake Map

# %% [markdown]
# ## I used the following websites to get me started:
#
# http://blog.dominodatalab.com/lesser-known-ways-of-using-notebooks/
# and
# https://app.dominodatalab.com/r00sj3/jupyter/view/batchdemo.ipynb

# %%
import pandas as pd
import folium
from matplotlib.colors import Normalize, rgb2hex
import matplotlib.cm as cm
# %matplotlib inline

# %% [markdown]
# ### Get the latest Earthquake data from USGS to compare against:
# http://earthquake.usgs.gov/earthquakes/map/

# %%
data = pd.read_csv('http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_day.csv')
data.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2018-12-21T01:34:30.080Z  36.152833 -118.075333   1.41  1.32      ml  11.0
# 1  2018-12-21T01:28:09.480Z  34.023500 -117.132333  10.55  1.00      ml  23.0
# 2  2018-12-21T01:22:40.550Z  33.500167 -116.796333   3.91  0.83      ml  33.0
# 3  2018-12-21T01:17:31.850Z  33.693333 -116.741667  16.17  0.81      ml  20.0
# 4  2018-12-21T01:17:20.600Z  61.523000 -149.908100  44.10  1.30      ml   NaN
#
#      gap     dmin   rms    ...                      updated  \
# 0  153.0  0.18190  0.11    ...     2018-12-21T01:37:57.748Z
# 1  160.0  0.02040  0.20    ...     2018-12-21T01:31:53.916Z
# 2   32.0  0.01263  0.17    ...     2018-12-21T01:26:19.942Z
# 3   68.0  0.02902  0.13    ...     2018-12-21T01:21:16.460Z
# 4    NaN      NaN  0.65    ...     2018-12-21T01:26:56.881Z
#
#                        place        type horizontalError depthError  magError  \
# 0    16km SSW of Olancha, CA  earthquake            0.28       1.25     0.250
# 1       5km S of Mentone, CA  earthquake            0.40       0.75     0.147
# 2      9km NE of Aguanga, CA  earthquake            0.21       0.47     0.142
# 3   6km SSW of Idyllwild, CA  earthquake            0.32       0.57     0.121
# 4  2km E of Big Lake, Alaska  earthquake             NaN       0.80       NaN
#
#    magNst     status  locationSource magSource
# 0    18.0  automatic              ci        ci
# 1    28.0  automatic              ci        ci
# 2    21.0  automatic              ci        ci
# 3    14.0  automatic              ci        ci
# 4     NaN  automatic              ak        ak
#
# [5 rows x 22 columns]

# %%
non_quakes = []
for i,j in enumerate(data.type):
    if j != "earthquake":
        non_quakes.append(i)
        print i
    else:
        pass
if len(non_quakes) == 0:
    print "All seismic activity recorded are earthquakes."
else:
    print "Seismic activity non-earthquakes are itmes: %r"%(non_quakes)
    pass
# Out:
# 41
# 69
# Seismic activity non-earthquakes are itmes: [41, 69]

# %%
# normalize the colors used based on max and min magnitudes of current earthquakes.
norm = Normalize(data['mag'].min(), data['mag'].max())

# %%
map = folium.Map(location=[48, -102], zoom_start=3) #, crs='EPSG4326')

for eq in data.iterrows():
    color = rgb2hex(cm.OrRd(norm(float(eq[1]['mag']))))
    info = eq[1]['place']+' at '+eq[1]['time']+'. Magnitude: '+str(eq[1]['mag'])
    map.circle_marker([eq[1]['latitude'], eq[1]['longitude']], 
                    popup= info, 
                    radius=20000*float(eq[1]['mag']),
                    line_color=color,
                    fill_color=color)

# save map as earthquake.html
map.save(outfile='figures/earthquake.html')
# Out:
# /Users/KimiZ/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:10: FutureWarning: circle_marker is deprecated. Use add_children(CircleMarker) instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # This newly created map can be used within future notebooks by using the following:

# %%
# %%HTML
# <iframe width="100%" height="350" src="figures/earthquake.html?inline=true"></iframe>
# Out:
# <iframe width="100%" height="350" src="figures/earthquake.html?inline=true"></iframe>

# %% [markdown]
# # Both maps are interactive.
